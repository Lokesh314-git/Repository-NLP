# %%
import re
import random

patterns = {
    r'hi|hello|hey': [
        "Hello!",
        "Hi there!",
        "Hey! How can I help you?"
    ],
    r'how are you': [
        "I am fine!",
        "Doing great!",
        "I am here to help you."
    ],
    r'what is your name': [
        "I am an NLP Chatbot.",
        "You can call me NLP Bot."
    ],
    r'bye|exit': [
        "Goodbye!",
        "See you soon!",
        "Have a great day!"
    ]
}

def chatbot_response(user_input):
    user_input = user_input.lower()
    for pattern, responses in patterns.items():
        if re.search(pattern, user_input):
            return random.choice(responses)
    return "Sorry, I didn't understand that."

# Chat loop
print("Chatbot: Hello! Type 'bye' to exit.")

while True:
    user_input = input("You: ")
    if user_input.lower() in ['bye', 'exit']:
        print("Chatbot:", chatbot_response(user_input))
        break
    print("Chatbot:", chatbot_response(user_input))
# Out:
# ==================================================
# 🤖 Enhanced Chatbot v2.0
# Type 'help' to see what I can do
# Type 'stats' to see conversation statistics
# Type 'save' to save our conversation
# Type 'load' to load previous conversation
# Type 'bye' to exit
# ==================================================
#
# No previous conversation found
# Chatbot: No previous conversation found
# Chatbot: Hello! How can I assist you today?
# Chatbot: Hello! How can I assist you today?
# Chatbot: Doing great! Ready to help you with anything.
# Chatbot: I'm still learning! Could you rephrase that or ask me something else?
# Chatbot: We've exchanged 4 messages over 74 seconds.
# Chatbot: No previous conversation found
# Chatbot: I'm still learning! Could you rephrase that or ask me something else?
